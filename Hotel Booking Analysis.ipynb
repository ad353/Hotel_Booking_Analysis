# %% [markdown]
# # **Project Name**    -  Hotel Booking Analysis

# %% [markdown]
# ##### **Project Type**    - EDA
# ##### **Contribution**    - Individual

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# Study of Hotel bookings related data is vital for any hospitality business as it gives insight into booking behaviour of customers as well as channels through which bookings are made.
#
# This project involves the analysis of the provided data set pertaining to Hotel bookings for City and Resort Hotels.
#
# Project activities have been categorised as under:
#
# - Defining the problem statement i.e. Business Objective of the study.
# - Collection and preparation of data by data cleaning , treating outliers etc.
# - Perform exploratory data analysis(EDA) through a deep study of relationship between different features, generate new variables based on need inline with related business objectives. Present the data in easily understandable form.
# - Provide observations as well as recommendations based on the EDA.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# https://github.com/ad353/Hotel_Booking_Analysis/blob/main/Hotel%20Booking%20Analysis.ipynb

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# In this project, we are going to analyze a Hotel Booking dataset. This dataset contains information about city hotels and resort hotels, including details about booking time, length of stay, the number of adults, children, and/or babies, as well as information about available parking spaces, among other things.
#
# The objective of this project is to explore and analyze the data to discover important factors related to hotel bookings and their attributes.

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# Maximise Bookings, Minimise Cancellations and Maximise Customer retention.

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
sns.set_style('darkgrid')

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Dataset Loading

# %%
# Load Dataset
dataset=pd.read_csv("Hotel Bookings.csv")

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look
dataset.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# 0                        0                     0       2  ...    No Deposit
# ...

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
print('No of rows are ',dataset.shape[0])
print('No of columns are ',dataset.shape[1])
# Out:
# No of rows are  119390
# No of columns are  32

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
dataset.duplicated().sum()
# Out:
# 31994

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
dataset.isnull().sum()
# Out:
# hotel                                  0
# is_canceled                            0
# lead_time                              0
# arrival_date_year                      0
# arrival_date_month                     0
# arrival_date_week_number               0
# arrival_date_day_of_month              0
# stays_in_weekend_nights                0
# stays_in_week_nights                   0
# adults                                 0
# children                               4
# babies                                 0
# meal                                   0
# country                              488
# market_segment                         0
# distribution_channel                   0
# is_repeated_guest                      0
# previous_cancellations                 0
# previous_bookings_not_canceled         0
# reserved_room_type                     0
# assigned_room_type                     0
# booking_changes                        0
# deposit_type                           0
# ...

# %%
# Visualizing the missing values
plt.figure(figsize=(10,6))
sns.heatmap(dataset.isnull(),cmap='viridis',yticklabels=False)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# The above dataset has 119390 rows and 32 columns. There are no null values in any columns except for 4 columns(children,country,agent,company). The dataset also have 31994 duplicate values

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
dataset.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type', 'agent',
#        'company', 'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date'],
#       dtype='object')

# %%
# Dataset Describe
dataset.describe()
# Out:
#          is_canceled      lead_time  arrival_date_year  \
# count  119390.000000  119390.000000      119390.000000
# mean        0.370416     104.011416        2016.156554
# std         0.482918     106.863097           0.707476
# min         0.000000       0.000000        2015.000000
# 25%         0.000000      18.000000        2016.000000
# 50%         0.000000      69.000000        2016.000000
# 75%         1.000000     160.000000        2017.000000
# max         1.000000     737.000000        2017.000000
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count             119390.000000              119390.000000
# mean                  27.165173                  15.798241
# std                   13.605138                   8.780829
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   28.000000                  16.000000
# ...

# %% [markdown]
# ### Variables Description

# %% [markdown]
# * **Hotel:**  H1= Resort Hotel, H2= City Hotel
# * **is_canceled** : If the booking was canceled(1) or not(0)
# * **lead_time** : Number of days that elapsed between the entering date of the  booking into the PMS(Property Management System) and the arrival date
# * **arrival_date_year** : Year of arrival date.
# * **arrival_date_month** : Month of arrival date.
# * **arrival_date_week_number** : Week number for arrival date.
# * **arrival_date_day_of_month**: Which day of the months guest is arriving.
# * **stays_in_weekend_nights**: Number of weekend nights (Saturday or Sunday) the guest stayed or booked to stay at the hotel.
# * **stays_in_week_nights**: Number of week nights (Monday to Friday) the guest stayed or booked to stay at the hotel.
# * **adults** : Number of adults.
# * **children** : Number of children.
# * **babies** : Number of babies.
# * **meal**: kind of meal opted for.
# * **country** : Country code.
# * **market_segment**: Which segment customer belongs to.
# * **distribution_channel** : How the customer accessed the stay- Corporate Booking/Direct/TA.TO
# * **is_repeated_guest** : The values indicating if the booking name was from a repeated guest (1) or not (0).
# * **previous_cancellations** : Was there a cancellation before.
# * **previous_bookings_not_canceled** : Count of previous bookings not cancelled.
# * **reserved_room_type** : Code of room type reserved.
# * **assigned_room_type** : Code for the type of room assigned to the booking.
# * **booking_changes** : Count of changes made to booking.
# * **deposit_type** : Deposit type.
# * **agent** : If the booking happens through agents or not.
# * **company** : If the booking happens through companies, the company ID that made the booking or responsible for paying the booking.
# * **days_in_waiting_list** : Number of days the booking was on the waiting list before the confirmation to the customer.
# * **customer_type** : Type of customer.
# * **adr** : Average Daily Rates that described via way of means of dividing the sum of all accommodations transactions using entire numbers of staying nights.
# * **required_car_parking_spaces** : How many parking areas are necessary for the customers.
# * **total_of_special_requests** : Total unique requests from consumers.
# * **reservation_status**: The last status of reservation, assuming one of three categories: Canceled – booking was cancelled by the customer; Check-Out;No-Show.
# * **reservation_status_date**: The last status date.

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.
for col in list(dataset.columns):
    print(f"{col} - No. of unique values: {dataset[col].nunique()}")
# Out:
# hotel - No. of unique values: 2
# is_canceled - No. of unique values: 2
# lead_time - No. of unique values: 479
# arrival_date_year - No. of unique values: 3
# arrival_date_month - No. of unique values: 12
# arrival_date_week_number - No. of unique values: 53
# arrival_date_day_of_month - No. of unique values: 31
# stays_in_weekend_nights - No. of unique values: 17
# stays_in_week_nights - No. of unique values: 35
# adults - No. of unique values: 14
# children - No. of unique values: 5
# babies - No. of unique values: 5
# meal - No. of unique values: 5
# country - No. of unique values: 177
# market_segment - No. of unique values: 8
# distribution_channel - No. of unique values: 5
# is_repeated_guest - No. of unique values: 2
# previous_cancellations - No. of unique values: 15
# previous_bookings_not_canceled - No. of unique values: 73
# reserved_room_type - No. of unique values: 10
# assigned_room_type - No. of unique values: 12
# booking_changes - No. of unique values: 21
# ...

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
# Creating the copy the dataset
df=dataset.copy()

# %% [markdown]
# #### Removing Duplicate rows

# %%
# Dropping the duplicate rows
df=df.drop_duplicates()

# %%
df.shape
# Out:
# (87396, 32)

# %% [markdown]
# #### Handling missing values

# %%
df['children'].fillna(0,inplace=True)
df['country'].fillna('Others',inplace=True)
df['company'].fillna(0,inplace=True)
df['agent'].fillna(0,inplace=True)

# %%
df.isnull().sum()
# Out:
# hotel                             0
# is_canceled                       0
# lead_time                         0
# arrival_date_year                 0
# arrival_date_month                0
# arrival_date_week_number          0
# arrival_date_day_of_month         0
# stays_in_weekend_nights           0
# stays_in_week_nights              0
# adults                            0
# children                          0
# babies                            0
# meal                              0
# country                           0
# market_segment                    0
# distribution_channel              0
# is_repeated_guest                 0
# previous_cancellations            0
# previous_bookings_not_canceled    0
# reserved_room_type                0
# assigned_room_type                0
# booking_changes                   0
# deposit_type                      0
# agent                             0
# company                           0
# days_in_waiting_list              0
# ...

# %% [markdown]
# #### Converting columns to appropriate datatypes.

# %%
# Converting datatype of columns 'children', 'company' and 'agent' from float to int.
df[['children', 'company', 'agent']] = df[['children', 'company', 'agent']].astype('int64')

# %%
# changing datatype of column 'reservation_status_date' to data_type.
df['reservation_status_date'] = pd.to_datetime(df['reservation_status_date'], format = '%Y-%m-%d')

# %% [markdown]
# #### Adding important columns.

# %%
df['total_stay'] = df['stays_in_weekend_nights']+df['stays_in_week_nights']

# Adding total people num as column, i.e. total people num = num of adults + children + babies
df['total_people'] = df['adults']+df['children']+df['babies']

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# - First thing we did was, make a copy of original dataset to work on.
# - We deleted all duplicated rows in copied Dataset.
# - Handled all null/missing values.
# - Then we changed the data types of columns to suitable data types.
# - Added new columns for better analysis.

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# ### Univariate Analysis

# %% [markdown]
# #### Chart - 1

# %%
plt.figure(figsize=(10,6))
sns.countplot(df['hotel'],palette='BuPu')
plt.title('Count of Hotels',fontsize=15)
plt.xlabel('Hotel Type',fontsize=12)
plt.ylabel('Count',fontsize=12)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Count plots help to quickly understand the distribution of categories within a categorical variable.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# City Hotels are more than Resort Hotels.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, the insights gained help create a positive business impact
#
# It reveals that one type of hotel is significantly more popular than others, the business could allocate more resources, marketing efforts, and investments towards that specific type. This could lead to higher occupancy rates and increased revenue.

# %% [markdown]
# #### Chart - 2

# %%
plt.figure(figsize=(10,6))
df['is_canceled'].value_counts().plot(kind='pie',autopct='%0.2f%%')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Pie charts are useful when we want to visualize the proportion or percentage that each category contributes to the total.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The pie chart reveals that a majority of bookings, approximately 72.51%, were not canceled, while around 27.49% of bookings were  canceled.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, the insights gained help create a positive business impact
#
# Understanding the proportion of canceled and non-canceled bookings helps businesses optimize their booking management strategies. They can identify patterns and factors contributing to cancellations and take steps to minimize them.

# %% [markdown]
# #### Chart - 3

# %%
plt.figure(figsize=(10,6))
sns.countplot(df['meal'])
plt.title('Distribution of Meal Options',fontsize=15)
plt.xlabel('Meal Type',fontsize=12)
plt.ylabel('Count',fontsize=12)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# We have multiple categories and want to compare their frequencies, a count plot can provide an easy visual comparison.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The meal option that is most favored by guests is "BB" (Bed and Breakfast).

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, the insights gained help create a positive business impact
#
# Understanding guest preferences allows the business to further tailor its menu to align with customer expectations. They can introduce variations or complementary offerings related to the "BB" meal option.

# %% [markdown]
# #### Chart - 4

# %%
plt.figure(figsize=(10,6))
sns.countplot(df['market_segment'],palette='magma')
plt.title('Distribution of Market Segments',fontsize=15)
plt.xlabel('Market Segment',fontsize=12)
plt.ylabel('Count',fontsize=12)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Count plots allow to compare the counts of different categories easily. We can quickly see which market segment has the highest count and how the counts vary across segments.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The higher count of "Online TA" and "Offline TA/TO" segments suggests that these are the more preferred booking channels for customers

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, the insights gained help create a positive business impact
#
# Capitalizing on the most preferred booking channels and segments can result in increased bookings and revenue. Promotions and offerings tailored to these segments can attract more customers.

# %% [markdown]
# #### Chart - 5

# %%
top_countries = df.groupby('country').size().sort_values(ascending=False).head(10)

# %%
top_countries.plot(kind='bar', figsize=(10, 6))
plt.title('Top 10 Countries',fontsize=15)
plt.xlabel('Country',fontsize=12)
plt.ylabel('Count',fontsize=12)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To show the distribution of countries.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Most of the guests came from PRT (Portugal),followed by GBR (United Kingdom), FRA (France), ESP (Spain) and DEU (Germany).

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, the insights gained help create a positive business impact
#
# Different nationalities might have distinct preferences for amenities, services, or cuisine. The insights can guide the business in tailoring offerings to cater to the preferences of guests from these top countries.

# %% [markdown]
# ### Bivariate and Multivariate Analysis

# %% [markdown]
# #### Chart - 6

# %%
plt.figure(figsize=(10,6))
sns.countplot(df['arrival_date_year'],hue=df['hotel'],palette='seismic')
plt.title('Year wise Bookings',fontsize=15)
plt.xlabel('arrival_date_year',fontsize=12)
plt.ylabel('Count',fontsize=12)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# It is easy to compare the distribution of bookings for different years and hotel types.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The highest number of bookings for both city hotels and resort hotels in the year 2016.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, the insights gained help create a positive business impact
#
# By understanding peak booking years, the business can adjust pricing strategies to maximize revenue during those periods, potentially offering special packages or promotions to attract more customers.

# %% [markdown]
# #### Chart - 7

# %%
plt.figure(figsize=(10,6))
sns.countplot(df['arrival_date_month'],hue=df['hotel'],palette='Set1')
plt.title('Monthly Guest Arrival',fontsize=15)
plt.xlabel('arrival_date_month',fontsize=12)
plt.ylabel('Count',fontsize=12)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# It easy to compare the distribution of bookings for different months and hotel types.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# In August, the maximum number of bookings for both city hotels and resort hotels was observed.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, the insights gained help create a positive business impact
#
# Pricing strategies can be adapted based on demand trends. Higher prices during high-demand months and attractive discounts during low-demand months can lead to increased revenue overall.

# %% [markdown]
# #### Chart - 8

# %%
plt.figure(figsize=(10,6))
sns.barplot(df['assigned_room_type'],y=df['total_people'])
plt.title('Total People by Assigned Room Type',fontsize=15)
plt.xlabel('Assigned Room Type',fontsize=12)
plt.ylabel('Total People',fontsize=12)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The bar chart visualizes the distribution of total people across different assigned room types. This can help identify which room types are more frequently booked for different group sizes.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Large groups tend to prefer room type H, while small groups show a preference for room type K.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, the insights gained help create a positive business impact
#
# Understanding which room types are preferred for different group sizes allows to manage room inventory more effectively.

# %% [markdown]
# #### Chart - 9

# %%
df_hotel=df.groupby('hotel')

# %%
avg_adr=df_hotel['adr'].mean().reset_index()

plt.figure(figsize=(10,6))
sns.barplot(x=avg_adr['hotel'],y=avg_adr['adr'],palette='GnBu')
plt.title("Avg ADR of each Hotel type",fontsize=15)
plt.xlabel('Hotel type',fontsize=12)
plt.ylabel('ADR',fontsize=12)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Bar plots are particularly effective when we are visualizing numerical data for different categories.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# City hotel has the highest ADR

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, the insights gained help create a positive business impact
#
# The higher ADR for the "City Hotel" compared to the "Resort Hotel" can positively impact the business's revenue, profitability, and market positioning.

# %% [markdown]
# #### Chart - 10

# %%
stay = df.groupby(['total_stay', 'hotel']).agg('count').reset_index()   
stay = stay.iloc[:, :3]                                                  
stay = stay.rename(columns={'is_canceled':'Number of stays'})

# %%
plt.figure(figsize=(15,8))
sns.barplot(x='total_stay',y='Number of stays',hue='hotel',data=stay,palette='YlGn')
plt.title('Optimal Stay Length in Both hotel types',fontsize=15)
plt.xlabel('total_stay_days',fontsize=12)
plt.ylabel('count of stays',fontsize=12)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Grouped bar plots are particularly useful for showing the frequency distribution of data across different categories.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Optimal stay in both the type hotel is less than 7 days.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, the insights gained help create a positive business impact
#
# Understanding the most common stay durations allows the hotel to allocate resources such as staff, cleaning, and inventory more effectively.

# %% [markdown]
# #### Chart - 11

# %%
bookings_by_months_df=df.groupby(['arrival_date_month','hotel'])['adr'].mean().reset_index()
months = ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']
bookings_by_months_df['arrival_date_month']=pd.Categorical(bookings_by_months_df['arrival_date_month'],categories=months,ordered=True)
bookings_by_months_df=bookings_by_months_df.sort_values('arrival_date_month')

# %%
plt.figure(figsize=(20,8))
sns.lineplot(x=bookings_by_months_df['arrival_date_month'],y=bookings_by_months_df['adr'],hue=bookings_by_months_df['hotel'])
plt.title('ADR across each month',fontsize=15)
plt.xlabel('Month',fontsize=12)
plt.ylabel('ADR',fontsize=12)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Line plots are especially effective for showing trends and patterns in data over time.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The months of June,July and August show higher Average Daily Rates (ADR) for Resort hotels compared to City hotels

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, the insights gained help create a positive business impact
#
# Charging higher ADR during peak months allows Resort hotels to maximize revenue and profitability, taking advantage of increased demand.

# %% [markdown]
# #### Chart - 12

# %%
plt.figure(figsize=(10,6))
sns.barplot(x=df['is_repeated_guest'],y= df['previous_bookings_not_canceled'],palette='Set2')
plt.title('Relationship Between repeated guests and previous bookings not cancelled.',fontsize=15)
plt.xlabel('is_repeated_guest',fontsize=12)
plt.ylabel('previous_bookings_not_canceled',fontsize=12)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Barplots make it easy to compare categories or groups visually.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Not Repeated guests are more likely to cancel their bookings.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Paying closer attention to feedback and reviews from first-time guests can provide insights into specific pain points they experience, allowing business to address these issues and improve guest satisfaction.

# %% [markdown]
# #### Chart - 13

# %%
market_segment_df=df[df['is_canceled']==1] 
market_segment_df
market_segment_df=market_segment_df.groupby(['market_segment','hotel']).size().reset_index().rename(columns={0:'counts'})

market_segment_df
# Out:
#    market_segment         hotel  counts
# 0        Aviation    City Hotel      45
# 1   Complementary    City Hotel      57
# 2   Complementary  Resort Hotel      31
# 3       Corporate    City Hotel     264
# 4       Corporate  Resort Hotel     246
# 5          Direct    City Hotel     912
# 6          Direct  Resort Hotel     825
# 7          Groups    City Hotel     890
# 8          Groups  Resort Hotel     445
# 9   Offline TA/TO    City Hotel    1261
# 10  Offline TA/TO  Resort Hotel     802
# 11      Online TA    City Hotel   12618
# 12      Online TA  Resort Hotel    5627
# 13      Undefined    City Hotel       2

# %%
plt.figure(figsize=(10,6))
sns.barplot(x='market_segment',y='counts',hue="hotel",data= market_segment_df,palette='turbo')
plt.title('Cancellation Rate Vs market_segment',fontsize=15)
plt.xlabel('market_segment',fontsize=12)
plt.ylabel('Counts',fontsize=12)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Barplots are useful for initial data exploration, allowing you to quickly identify patterns and trend in data

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Online T/A  has the highest cancellation rate.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# By addressing the issues leading to cancellations in specific segments, we can improve customer retention and loyalty, which can have a positive impact on long-term revenue.

# %% [markdown]
# #### Chart - 14

# %%
plt.figure(figsize=(12,10))
sns.countplot(df['arrival_date_week_number'],hue=df['hotel'],orient='v',palette='Set1')
plt.title('Weekly Guest Arrival',fontsize=15)
plt.xlabel('arrival_date_week_number',fontsize=12)
plt.ylabel('Count',fontsize=12)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# It easy to compare the distribution of bookings for different weeks and hotel types.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# In week 32,33 and 34 the maximum number of bookings for both city hotels and resort hotels was observed.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?

# %% [markdown]
# Pricing strategies can be adapted based on demand trends. Higher prices during high-demand weeks and attractive discounts during low-demand weeks can lead to increased revenue overall.

# %% [markdown]
# #### Chart - 15

# %%
df2=df[df['adr']<5000]

# %%
plt.figure(figsize=(16,8))
sns.scatterplot(x=df2['total_stay'],y=df2['adr'])
plt.title('Relationship between  adr and total stay',fontsize=15)
plt.xlabel('total stay',fontsize=12)
plt.ylabel('adr',fontsize=12)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Scatter plots are excellent for identifying relationships between two continuous variables. They can reveal correlations, patterns, clusters, outliers, and trends that may not be apparent in other types of charts.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From above scatter chart we can say that as the stay increases adr is decreasing. Thus for longer stays customer can get good adr.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?

# %% [markdown]
# This insight can inform pricing strategies. It may suggest that offering lower ADRs for longer stays can attract and retain customers, resulting in increased occupancy rates and revenue.

# %% [markdown]
# #### Chart - 16

# %%
plt.figure(figsize=(18,6))
df3=df.groupby(['market_segment','hotel','is_canceled'])['adr'].mean().reset_index() 
sns.barplot(x='market_segment',y='adr',hue='hotel',data=df3.sort_values(by='adr',ascending=False))
plt.title('Adr across market segment',fontsize=15)
plt.xlabel('market segment',fontsize=12)
plt.ylabel('adr',fontsize=12)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Bar plots are excellent for comparing data among different categories or groups. The length or height of the bars is directly proportional to the values they represent, allowing for a quick visual comparison.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# 'Direct' and 'Online TA' are contributing the most in both types of hotels.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?

# %% [markdown]
# Knowing that 'Direct' and 'Online TA' are strong market segments, the hotel can allocate more resources and marketing efforts to target these segments. This can result in increased bookings and revenue from these channels.

# %% [markdown]
# #### Chart - 17

# %%
plt.figure(figsize=(10,8))
waiting_time_df=df.groupby('hotel')['days_in_waiting_list'].mean().reset_index()
sns.barplot(x=waiting_time_df['hotel'],y=waiting_time_df['days_in_waiting_list'],palette='husl')
plt.xlabel('Hotel type',fontsize=15)
plt.ylabel('waiting time',fontsize=12)
plt.title("Waiting time for each hotel type",fontsize=12)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Bar plots are excellent for comparing data among different categories or groups.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# City Hotels has longer waiting period than the Resort Hotels. Thus we can say that City Hotels are much busier than the Resort Hotels

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?

# %% [markdown]
# Knowing that City Hotels are busier can help in the allocation of resources such as staffing and inventory. This can ensure that City Hotels are adequately prepared to handle higher demand, leading to improved customer service and satisfaction.

# %% [markdown]
# #### Chart - 18

# %%
df4=df[['lead_time','previous_cancellations','previous_bookings_not_canceled','is_repeated_guest','booking_changes','days_in_waiting_list','adr','required_car_parking_spaces','total_of_special_requests','total_stay','total_people']]

# %%
plt.figure(figsize=(12,6))
sns.heatmap(df4.corr(),annot = True,fmt='.2f')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Heatmaps are excellent for detecting patterns, correlations, and trends in large datasets. They can reveal hidden insights that may not be apparent in raw tabular data.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# - adr is slightly correlated with total_people, which makes sense as more no. of people means more revenue, therefore more adr.
# - is_repeated guest and previous bookings not canceled has strong corelation. May be repeated guests are not more likely to cancel their bookings.

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?

# %% [markdown]
# Our business objective was to increase bookings, decrease cancellations, and increase customer retention while also extending stays. Based on our investigation, some recommendations we came up with are as follows:
#
# - Agents and market sectors that bring in more clients should also be recognised with awards and incentives.
#
# - Cancellations had a strong connection with new clients. If new clients are prone to cancel, further efforts should be taken to retain them by providing discounts and offers. Additionally, greater efforts should be made to retain clients as Repeated clients generally cancel less bookings.
#
# - Good customer evaluations can have a significant impact on a hotel's brand value, and it is important to consider customer feedback and reviews in order to improve hotel amenities and the guest experience.
#
# - Launching customer loyalty programmes to reward loyal customers.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# - City hotels are the most preferred hotel type by the guests.
#
# - 27.5 % bookings were got cancelled out of all the bookings.
#
# - BB( Bed & Breakfast) is the most preferred type of meal by the guests.
#
# - "Online TA" and "Offline TA/TO" are the more preferred booking channels.
#
# - Most of the bookings for City hotels and Resort hotel were happened in 2016.
#
# - In August, the maximum number of bookings for both city hotels and resort hotels was observed.
#
# - Optimal stay in both the type hotel is less than 7 days.
#
# - The months of June,July and August show higher Average Daily Rates (ADR) for Resort hotels compared to City hotels.
#
# - In week 32,33 and 34 the maximum number of bookings for both city hotels and resort hotels was observed.
#
# - City Hotels has longer waiting period than the Resort Hotels. Thus we can say that City Hotels are much busier than the Resort Hotels.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA Capstone Project !!!***
